# %% [markdown]
# Wstępne przetwarzanie danych

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("reviews_all.csv")

# %%
df1 = pd.read_excel("review_links_books_1a.xlsx")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5972 entries, 0 to 5971
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Link do recenzji  5972 non-null   object
# dtypes: object(1)
# memory usage: 46.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5974 entries, 0 to 5973
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          5974 non-null   int64
#  1   Link                5974 non-null   object
#  2   Autor               5970 non-null   object
#  3   Tytuł               5970 non-null   object
#  4   Data_recenzji       5964 non-null   object
#  5   Treść_recenzji      5974 non-null   object
#  6   Średnia_ocen        5970 non-null   float64
#  7   Liczba_ocen         5969 non-null   float64
#  8   Liczba_czytelników  5970 non-null   float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 420.2+ KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Link', 'Autor', 'Tytuł', 'Data_recenzji',
#        'Treść_recenzji', 'Średnia_ocen', 'Liczba_ocen', 'Liczba_czytelników'],
#       dtype='object')

# %% [markdown]
# # W pliku wyjściowym z pobranymi linkami do recenzji mam 5972 rekordy.
# # W pliku "ostatecznym" mam 2 rekordy więcej.
# # Prawdopodobnie podczas pobierania recenzji, któreś linki się zdublowały.
# # Usunę duble (może jest ich więcej)

# %%
# Usywam duplikaty
df = df.drop_duplicates(["Link", "Autor", "Tytuł", "Data_recenzji", "Treść_recenzji", "Średnia_ocen", "Liczba_ocen", "Liczba_czytelników"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5972 entries, 0 to 5973
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          5972 non-null   int64
#  1   Link                5972 non-null   object
#  2   Autor               5968 non-null   object
#  3   Tytuł               5968 non-null   object
#  4   Data_recenzji       5962 non-null   object
#  5   Treść_recenzji      5972 non-null   object
#  6   Średnia_ocen        5968 non-null   float64
#  7   Liczba_ocen         5967 non-null   float64
#  8   Liczba_czytelników  5968 non-null   float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 466.6+ KB

# %% [markdown]
# # Na chwilę obecną mam 5972 rekordy.
# # Teraz typ zmiennych 'Liczba_ocen', 'Liczba_czytelników' zamienię na int.
# # Typ zmiennej 'Data_recenzji' zmienię na date.

# %%
# Zmieniam typ zmiennej "Liczba_ocen"
df["Liczba_ocen"] = df["Liczba_ocen"].fillna(0).astype(int)

# %%
# Zmieniam typ zmiennej "Liczba_czytelników"
df["Liczba_czytelników"] = df["Liczba_czytelników"].fillna(0).astype(int)

# %%
# Zmieniam typ zmiennej "Data_recenzji"
df["Data_recenzji"] = pd.to_datetime(df["Data_recenzji"], format="%Y-%m-%d")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5972 entries, 0 to 5973
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          5972 non-null   int64
#  1   Link                5972 non-null   object
#  2   Autor               5968 non-null   object
#  3   Tytuł               5968 non-null   object
#  4   Data_recenzji       5962 non-null   datetime64[ns]
#  5   Treść_recenzji      5972 non-null   object
#  6   Średnia_ocen        5968 non-null   float64
#  7   Liczba_ocen         5972 non-null   int32
#  8   Liczba_czytelników  5972 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(1), object(4)
# memory usage: 419.9+ KB

# %%
# Resetuję indeksy
df = df.reset_index(drop=True)

# %%
# Usuwam pierwsza kolumnę "Unnamed: 0"
df = df.drop(df.columns[0], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5972 entries, 0 to 5971
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Link                5972 non-null   object
#  1   Autor               5968 non-null   object
#  2   Tytuł               5968 non-null   object
#  3   Data_recenzji       5962 non-null   datetime64[ns]
#  4   Treść_recenzji      5972 non-null   object
#  5   Średnia_ocen        5968 non-null   float64
#  6   Liczba_ocen         5972 non-null   int32
#  7   Liczba_czytelników  5972 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(2), object(4)
# memory usage: 326.7+ KB

# %% [markdown]
# # W kilku przypadkach mam braki danych

# %%
# Wyświetlam braki danych we wszystkich zmiennych
df[df.isna().any(axis=1)]
# Out:
#                                                    Link                 Autor  \
# 3142  https://lubimyczytac.pl/oficjalne-recenzje-ksi...       Brigid Kemmerer
# 3190  https://lubimyczytac.pl/oficjalne-recenzje-ksi...  Agnieszka Stelmaszyk
# 4365  https://lubimyczytac.pl/oficjalne-recenzje-ksi...        Colleen Hoover
# 4507  https://lubimyczytac.pl/oficjalne-recenzje-ksi...         Lewis Carroll
# 4700  https://lubimyczytac.pl//6048/dawno-temu-na-li...                   NaN
# 4751          https://lubimyczytac.pl//5918/syreni-czar                   NaN
# 4766  https://lubimyczytac.pl//5870/milosc-w-cieniu-...                   NaN
# 4767  https://lubimyczytac.pl//5865/tam-kolo-mlyna-r...                   NaN
# 4932  https://lubimyczytac.pl/oficjalne-recenzje-ksi...           Philip Roth
# 5420  https://lubimyczytac.pl/oficjalne-recenzje-ksi...             Shaun Tan
#
#                                                   Tytuł Data_recenzji  \
# 3142                                 Listy do utraconej           NaT
# 3190              Imaginarium. Tom 1. Gildia Wynalazców           NaT
# 4365                                          Ugly Love           NaT
# 4507  Po drugiej stronie Lustra i co tam Alicja znal...           NaT
# 4700                                                NaN           NaT
# 4751                                                NaN           NaT
# 4766                                                NaN           NaT
# 4767                                                NaN           NaT
# 4932                               Amerykańska sielanka           NaT
# 5420                               Zgubione, znalezione           NaT
#
#                                          Treść_recenzji  Średnia_ocen  \
# 3142  Juliet, zostawia odręcznie pisane listy na gro...           8.2
# 3190  Zwariowana i niepokorna Marianna w zielonym ko...           8.4
# 4365  Miłość została wpleciona do tysięcy fabuł ksią...           7.9
# 4507  „Alicja” Lewisa Carrolla jest tak bardzo obecn...           7.1
# 4700                                                              NaN
# 4751                                                              NaN
# 4766                                                              NaN
# 4767                                                              NaN
# 4932  Pewna pokaźna część ludzkości od przeszło już ...           7.4
# 5420  Shaun Tan jest kapłanem wyobcowania. To znaczy...           8.2
#
#       Liczba_ocen  Liczba_czytelników
# 3142         1554                3577
# 3190           65                 182
# 4365        10893               20529
# 4507         1205                2442
# 4700            0                   0
# 4751            0                   0
# 4766            0                   0
# 4767            0                   0
# 4932          674                2338
# 5420           91                 221

# %% [markdown]
# **NaN (Not a Number); NaT (Not a Time)

# %% [markdown]
# # W 4 przypadkach nie mam pobranych żadnych recenzji. Sprawdziłam, i wiem, że te recenzje zostały usunięte. Więc te 4 rekordy usunę (index 4700, 4751, 4766, 4767)

# %%
# Usuwam rekordy dla indeksów: 4700, 4751, 4766, 4767
to_drop = [4700, 4751, 4766, 4767]
df = df.drop(to_drop, axis=0)

# %% [markdown]
# # Teraz uzupełnię braki w datach recenzji

# %%
# Uzupełniam braki danych w datach na podstawie najbliższych rekordów.
# Użyję metody "ffill" - uzupełnia braki danych wartościami z poprzednich rekordów (metoda "bfill" z następnych rekordów).
df["Data_recenzji"] = df["Data_recenzji"].fillna(method="ffill")
# Out:
# C:\Users\konta\AppData\Local\Temp\ipykernel_11596\2618223451.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Data_recenzji'] = df['Data_recenzji'].fillna(method='ffill')

# %%
df.iloc[5415]
# Out:
# Link                  https://lubimyczytac.pl/oficjalne-recenzje-ksi...
# Autor                                                     Sue Monk Kidd
# Tytuł                                                   Czarne skrzydła
# Data_recenzji                                       2014-09-11 00:00:00
# Treść_recenzji        Pamiętam, że serial „Północ-Południe” (na pods...
# Średnia_ocen                                                        7.4
# Liczba_ocen                                                        1962
# Liczba_czytelników                                                 4653
# Name: 5419, dtype: object

# %%
df.iloc[5416]
# Out:
# Link                  https://lubimyczytac.pl/oficjalne-recenzje-ksi...
# Autor                                                         Shaun Tan
# Tytuł                                              Zgubione, znalezione
# Data_recenzji                                       2014-09-11 00:00:00
# Treść_recenzji        Shaun Tan jest kapłanem wyobcowania. To znaczy...
# Średnia_ocen                                                        8.2
# Liczba_ocen                                                          91
# Liczba_czytelników                                                  221
# Name: 5420, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5968 entries, 0 to 5971
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Link                5968 non-null   object
#  1   Autor               5968 non-null   object
#  2   Tytuł               5968 non-null   object
#  3   Data_recenzji       5968 non-null   datetime64[ns]
#  4   Treść_recenzji      5968 non-null   object
#  5   Średnia_ocen        5968 non-null   float64
#  6   Liczba_ocen         5968 non-null   int32
#  7   Liczba_czytelników  5968 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(2), object(4)
# memory usage: 373.0+ KB

# %%
# Zmieniam typ zmiennej "Data_recenzji" podczas powyższych zmian wskoczył mi dodatkowo format godziny, nie potrzebuję tego.
df["Data_recenzji"] = pd.to_datetime(df["Data_recenzji"], format="%Y-%m-%d")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5968 entries, 0 to 5971
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Link                5968 non-null   object
#  1   Autor               5968 non-null   object
#  2   Tytuł               5968 non-null   object
#  3   Data_recenzji       5968 non-null   datetime64[ns]
#  4   Treść_recenzji      5968 non-null   object
#  5   Średnia_ocen        5968 non-null   float64
#  6   Liczba_ocen         5968 non-null   int32
#  7   Liczba_czytelników  5968 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(2), object(4)
# memory usage: 373.0+ KB

# %%
# Sprawdzę czy dana książka ma tylko jedną recenzję czy więcej i zapisze te rekordy do osobnej df
# keep=False oznacza, że wszystkie wystąpienia duplikatów zostaną oznaczone jako True
df_duplicate_books = df[df.duplicated(subset=["Autor", "Tytuł"], keep=False)]

# %%
# Nie ma tych rekordów dużo, więc chcę je wszystkie wyświetlić.
pd.set_option("display.max_rows", None)

# %%
df_duplicate_books.sort_values(by=["Autor", "Tytuł", "Data_recenzji"])
# Out:
#                                                    Link  \
# 4650  https://lubimyczytac.pl/oficjalne-recenzje-ksi...
# 325                https://lubimyczytac.pl/zanim-zgasna
# 5868  https://lubimyczytac.pl/oficjalne-recenzje-ksi...
# 2337  https://lubimyczytac.pl/oficjalne-recenzje-ksi...
# 1285  https://lubimyczytac.pl/dzieje-domu-towarowego...
# 1116  https://lubimyczytac.pl/dzieje-domu-towarowego...
# 1231              https://lubimyczytac.pl/niezwyciezeni
# 1173   https://lubimyczytac.pl/niezwyciezeni-2021-01-13
# 4803  https://lubimyczytac.pl/oficjalne-recenzje-ksi...
# 3708  https://lubimyczytac.pl/oficjalne-recenzje-ksi...
# 5843  https://lubimyczytac.pl/oficjalne-recenzje-ksi...
# 160   https://lubimyczytac.pl/otuchy-na-prozno-szukacie
# 4562  https://lubimyczytac.pl/oficjalne-recenzje-ksi...
# 
# 4658  „Zatracenie”, ostatnia książka Osamu Dazai nap...           7.8
# 1291  Kiedy zapragniemy zgłębić historię powstania „...           7.8
# 139   Wiatr napiera na żagle, słychać trzeszczenie l...           8.1
# 87    Wiatr napiera w żagle, słychać trzeszczenie li...           8.1
# 5621  Nie tak dawno minęła siedemdziesiąta rocznica ...           7.1
# 2133  Najwyższa nagroda w Cassino, zdobycie opactwa,...           7.2
# 3644  Choć „Syn” opowiada o dziejach potężnego rodu ...           7.5
# 724   Eli McCullough w ciągu stu lat życia poznał Dz...           7.5
# 5207  Remigiusz Mróz jako powieściopisarz zadebiutow...           7.2
# 3348  Mamy rok 1940, właśnie toczy się bitwa o Angli...           6.8
# 5829  Dobry Niemiec to martwy Niemiec – te słowa, kt...           6.9
# 2239  – Właścicielem willi jest Herr Lubert, archite...           6.7
# 2846  Robert Harris jest pisarzem, który nie zawodzi...           6.6
# 669   Świat staje na krawędzi wojny. To czas, w któr...           6.6
# 3796  Stało się coś strasznego, ale nic nie pamiętam...           6.6
# 505   Ruth Ware to zdecydowanie jedno z najmocniejsz...           6.6
# 4858  Londyn 1947 roku. Europa dźwiga się z wojennej...           6.5
# 543   Sarah Waters to autorka, która zawsze gdzieś t...           6.4
# 1703  Czy jesteście skłonni powiedzieć o sobie wszys...           6.6
# 1632  Mógłbym, drodzy Państwo, zainspirować się tytu...           6.6
# 3933  Wznowiona właśnie przez Wydawnictwo Literackie...           7.6
# 932   Stanisław Lem w swoich powieściach i opowiadan...           7.5
# 4228  Każdy człowiek potrzebuje w swoim życiu pewnoś...           7.1
# 1809  Muszę się obudzić, pomyślał, choćby po to, żeb...           7.2
# 3103  Ileż to już razy na kartach książek przewijali...           6.9
# 3069  Ileż to już razy na kartach książek przewijali...           6.9
# 5565  Mniej więcej w kwietniu tego roku światło dzie...           7.4
# 643   Jestem, drodzy Państwo, szczerym zwolennikiem ...           7.4
# 5841  Każdy, kto choć trochę interesuje się literatu...           7.4
# 988   „Reportaż nie znosi fantazji. Czy kobiety na f...           7.4
# 2628  Chciałoby się, żeby 100. rocznica odzyskania n...           6.9
# 2517  „Celem tej książki jest zaprezentowanie obrazu...           6.9
#
#       Liczba_ocen  Liczba_czytelników
# 4650         4801               14575
# 325          5748               17988
# 5868          439                1391
# 2337          917                3003
# 1285          436                1104
# 1116           38                  98
# 1231         1019                2672
# 1173         1019                2672
# 4803         5547               11133
# 3708        12253               24424
# 5843          324                1114
# 160           429                1582
# 4562          551                2118
# 1275          767                3172
# 4826         1796                5046
# 1521         3098                8230
# 3715           92                 348
# 2453          250                 919
# 3984         1973                4423
# 994          6147               13219
# 3137          952                1729
# 642          1479                2567
# 4916          220                 667
# 881           321                 898
# 3016          681                1665
# 1137         1048                2512
# 5066          724                1715
# 1742          697                1493
# 2583         3538                6405
# 306          3998                7342
# 5823          724                1588
# 3774         1448                3052
# 5381         7063               13153
# 1253          947                1820
# 5132          803                2048
# 956          1692                3804
# 4426          879                1865
# 2544          818                2130
# 3331         1369                3053
# 2892         1369                3053
# 4296          219                 693
# 1084          438                1228
# 4739          106                 214
# 1379          150                 347
# 5842          455                1040
# 2990         1743                3363
# 4289          191                 800
# 869           367                1309
# 3271         1468                4480
# 289          3162                8910
# 4658          474                1281
# 1291         1602                3948
# 139           192                 393
# 87            192                 393
# 5621           31                 159
# 2133           67                 291
# 3644         1109                3101
# 724          1297                3702
# 5207          217                 792
# 3348         1406                3483
# 5829          318                 982
# 2239          487                1337
# 2846          293                 615
# 669           413                 831
# 3796          361                1069
# 505          1141                2529
# 4858          235                 736
# 543           469                1282
# 1703          718                2211
# 1632          718                2211
# 3933          130                 378
# 932           321                 839
# 4228         2999                5628
# 1809         1300                2235
# 3103          238                 575
# 3069          238                 575
# 5565          222                 922
# 643           478                1874
# 5841          963                2463
# 988          1174                2949
# 2628           42                 145
# 2517           42                 145

# %%
## ** opcjonalnie** Zapisuję do ramki danych i pliku xlsx te duplikaty
duplicate_books = pd.DataFrame(df_duplicate_books)
duplicate_books.to_excel("duplicate_books.xlsx")

# %% [markdown]
# ### Jak widać, kilka tytułów (książek) ma więcej niż jedną tzw. oficjalna recenzję.
# ### Do tego w przypadku 6 książek, recenzja jest ta sama (ten sam autor i ta sama treść). Poza linkiem różnią się datą dodania.
# ### Muszę zwrócić uwagę, co do treści recenzji - sama treść jest identyczna, natomiast podczas scrapowania zaciągnął się fragment dotyczący ile osób poleca recenzje pod danym linkiem. I tu się rozjeżdża ta identyczność. Dlatego podczas usuwania rekordów nie będę odwoływała się do zmiennej 'Treść_recenzji'.
# ### Na potrzeby tego projektu, zostawię recenzje wcześniejsze (dotyczy to 6 rekordów).
# ### Pozostałe tytuły będą miały wszystkie zeskarpowane recenzje (mają róznych autorów, więc uważam, że warto to zostawić).

# %%
# W związku z tym, że podczas scrapowania nie pobrałam autorów recenzji
#(żeby nie marnować czasu na ponowne scrapowanie - sprawdziłam te 6 tytułów w necie),
# do usunięcia zbędnych rekordów posłużę się zmiennymi "Autor", "Tytuł", "Data_recenzji" oraz indeksami.
rows_to_drop = df.query("index in [1116, 1173, 2892, 1379, 87, 3069]")

# %%
# Usuwam rekordy dla indeksów: 1116, 1173, 2892, 1379, 87, 3069
to_drop = [1116, 1173, 2892, 1379, 87, 3069]
df = df.drop(to_drop, axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5962 entries, 0 to 5971
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Link                5962 non-null   object
#  1   Autor               5962 non-null   object
#  2   Tytuł               5962 non-null   object
#  3   Data_recenzji       5962 non-null   datetime64[ns]
#  4   Treść_recenzji      5962 non-null   object
#  5   Średnia_ocen        5962 non-null   float64
#  6   Liczba_ocen         5962 non-null   int32
#  7   Liczba_czytelników  5962 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(2), object(4)
# memory usage: 372.6+ KB

# %% [markdown]
# # Dodam jeszcze zmienną z samym rokiem. Później może się przydać.

# %%
df["Rok_recenzji"] = df["Data_recenzji"].dt.year

# %%
# To będzie moja wyjściowa ramka danych do dalszych prac. Zapiszę ją do pliku csv.
reviews_eda1 = pd.DataFrame(df)
reviews_eda1.to_csv("reviews_eda1.csv")
